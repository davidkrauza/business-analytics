# %% [markdown]
# # Business Analytics - Unit 04
#
# ## Lab 03 - Data Exploration
#
# ### Introduction
#
# The purpose of this lab is to introduce how Python can be used to tidy messy datasets. After completing this lab the student should be able to use Python to:
#
# 1. Generate descriptive statistics using Python
# 2. Generate data visualizations using Python
#
# ### 1. Generate descriptive statistics using Python
#
# As with Lab 02, we will start off by importing the pandas library, but we are also going to use the iris dataset that comes with the Python. The data set consists of 50 samples from each of three species of Iris (Iris setosa, Iris virginica and Iris versicolor). Four features are measured from each sample: the length and the width of the sepals and petals, in centimetres

# %%
import pandas as pd
import numpy as np
from sklearn import datasets
iris = datasets.load_iris()
df = pd.DataFrame(data= np.c_[iris['data'], iris['target']],
                       columns= iris['feature_names'] + ['target'])
df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# 5                  5.4               3.9                1.7               0.4
# 6                  4.6               3.4                1.4               0.3
# 7                  5.0               3.4                1.5               0.2
# 8                  4.4               2.9                1.4               0.2
# 9                  4.9               3.1                1.5               0.1
# 10                 5.4               3.7                1.5               0.2
# ...

# %% [markdown]
# The iris dataset is not stored in a pandas dataframe, so we had to create a panads dataframe with it.

# %%
df['sepal length (cm)'].describe()
# Out:
# count    150.000000
# mean       5.843333
# std        0.828066
# min        4.300000
# 25%        5.100000
# 50%        5.800000
# 75%        6.400000
# max        7.900000
# Name: sepal length (cm), dtype: float64

# %% [markdown]
# The process of displaying descriptive statistics in Python is super easy. The pandas library give us all the functions we need to generate them. As you can see from the previous code block we picked one column in the dataframe and called the describe() and Python printed the count of items, measures of central tendency, and interquartile ranges.

# %%
df.groupby(by='target').describe()
# Out:
#               petal length (cm)  petal width (cm)  sepal length (cm)  \
# target
# 0.0    count          50.000000         50.000000          50.000000
#        mean            1.464000          0.244000           5.006000
#        std             0.173511          0.107210           0.352490
#        min             1.000000          0.100000           4.300000
#        25%             1.400000          0.200000           4.800000
#        50%             1.500000          0.200000           5.000000
#        75%             1.575000          0.300000           5.200000
#        max             1.900000          0.600000           5.800000
# 1.0    count          50.000000         50.000000          50.000000
#        mean            4.260000          1.326000           5.936000
#        std             0.469911          0.197753           0.516171
#        min             3.000000          1.000000           4.900000
# ...

# %% [markdown]
# Getting the descriptive statistics for one column is not partiuarly useful. You'll want to see them for each type of Iris (enumerated as 0 to 2 in the target column in this dataset). To look at the descriptive statistics for each type, you'll first groupby the target then call the describe() function.

# %%
df['petal length (cm)'].median()
# Out:
# 4.35

# %%
df.groupby('target').median()
# Out:
#         sepal length (cm)  sepal width (cm)  petal length (cm)  \
# target
# 0.0                   5.0               3.4               1.50
# 1.0                   5.9               2.8               4.35
# 2.0                   6.5               3.0               5.55
#
#         petal width (cm)
# target
# 0.0                  0.2
# 1.0                  1.3
# 2.0                  2.0

# %%
df['petal length (cm)'].var()
# Out:
# 3.1131794183445156

# %%
df.groupby(by='target').var()
# Out:
#         sepal length (cm)  sepal width (cm)  petal length (cm)  \
# target
# 0.0              0.124249          0.145180           0.030106
# 1.0              0.266433          0.098469           0.220816
# 2.0              0.404343          0.104004           0.304588
#
#         petal width (cm)
# target
# 0.0             0.011494
# 1.0             0.039106
# 2.0             0.075433

# %%
df.groupby(by='target').corr()
# Out:
#                           petal length (cm)  petal width (cm)  \
# target
# 0.0    petal length (cm)           1.000000          0.306308
#        petal width (cm)            0.306308          1.000000
#        sepal length (cm)           0.263874          0.279092
#        sepal width (cm)            0.176695          0.279973
# 1.0    petal length (cm)           1.000000          0.786668
#        petal width (cm)            0.786668          1.000000
#        sepal length (cm)           0.754049          0.546461
#        sepal width (cm)            0.560522          0.663999
# 2.0    petal length (cm)           1.000000          0.322108
#        petal width (cm)            0.322108          1.000000
#        sepal length (cm)           0.864225          0.281108
#        sepal width (cm)            0.401045          0.537728
#
#                           sepal length (cm)  sepal width (cm)
# target
# 0.0    petal length (cm)           0.263874          0.176695
# ...

# %% [markdown]
# The last five code blocks did essentially the same thing we did with the describe function but with median and variance.
#
# ### 2. Generate data visualizations using Python
#
# To create data visuzalizations two libraries are available to generate the graphs and one is built into the pandas dataframe. The two libraries are:
# 1. matplotlib - 2D plotting library which produces publication quality figures in a variety of hardcopy formats and interactive environments across platforms
# 2. seaborn - which is actual built on top of the seaborn library
#
# %matplotlib inline in a Notebook causes plots to be shown as static images, only 1 call to %matplotlib inline is required.

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df.groupby(by='target')['sepal length (cm)'].mean().plot(kind='bar')

# %%
df.plot(kind='scatter', x='sepal length (cm)', y='sepal width (cm)')

# %%
df['sepal length (cm)'].hist()

# %%
df.groupby(by='target').hist()
# Out:
# target
# 0.0    [[Axes(0.125,0.563043;0.336957x0.336957), Axes...
# 1.0    [[Axes(0.125,0.563043;0.336957x0.336957), Axes...
# 2.0    [[Axes(0.125,0.563043;0.336957x0.336957), Axes...
# dtype: object

# %% [markdown]
# Calling the plot function on a pandas dataframe creates a graph for you. The examples in the last four graphs show a line graph, a scatter plot, and histograms.

# %%
#create some data
x_series = [0,1,2,3,4,5]
y_series_1 = [x**2 for x in x_series]
y_series_2 = [x**3 for x in x_series]

#plot the two lines
plt.plot(x_series, y_series_1)
plt.plot(x_series, y_series_2)

# %% [markdown]
# A matplotlib visualization works very similar to the pandas dataframe, but it more robust.

# %%
fig = sns.FacetGrid(df, hue='target', size=5).map(plt.scatter, 'sepal length (cm)', 'sepal width (cm)').add_legend()

# %% [markdown]
# Finally, the seaborn package allows the most control over the contruction of a graph.
